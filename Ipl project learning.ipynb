# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly as pt
import cufflinks as cf

# %%
df=pd.read_csv('ipl.csv')
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     str
#  2   venue                74 non-null     str
#  3   team1                74 non-null     str
#  4   team2                74 non-null     str
#  5   stage                74 non-null     str
#  6   toss_winner          74 non-null     str
#  7   toss_decision        74 non-null     str
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     str
#  13  won_by               74 non-null     str
#  14  margin               74 non-null     int64
#  15  player_of_the_match  74 non-null     str
# ...

# %%
df.shape
# Out:
# (74, 20)

# %%
match_winners=df['match_winner'].value_counts()
sns.barplot(y=match_winners.index,x=match_winners.values,palette='viridis')
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_11004\1452133156.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=match_winners.index,x=match_winners.values,palette='viridis')
# <Axes: ylabel='match_winner'>

# %%
sns.countplot(x=df['toss_decision'],palette='icefire')
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_11004\2883208762.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['toss_decision'],palette='icefire')
# <Axes: xlabel='toss_decision', ylabel='count'>

# %%
df[df['toss_winner']==df['match_winner']]['match_id'].count()
# Out:
# np.int64(36)

# %%
sns.countplot(x=df['won_by'])
# Out:
# <Axes: xlabel='won_by', ylabel='count'>

# %%
counts=df['player_of_the_match'].value_counts().head()
sns.barplot(x=counts.values,y=counts.index)
# Out:
# <Axes: ylabel='player_of_the_match'>

# %%
score=df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)
sns.barplot(score)
# Out:
# <Axes: xlabel='top_scorer', ylabel='highscore'>

# %%
df['wickets'] = df['best_bowling_figure'].str.split('--').str[0].astype(int)
df['runs']    = df['best_bowling_figure'].str.split('--').str[1].astype(int)
best = df.sort_values(['wickets', 'runs'], ascending=[False, True]).iloc[0]

print(best['best_bowling'])     
print(best['best_bowling_figure'])
# Out:
# Jasprit Bumrah
# 5--10

# %%
df[df['won_by']=='Runs'].sort_values(by='margins',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91
